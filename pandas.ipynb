# %%
import pandas as pd

# %%
df = pd.read_csv('C:\\Users\\viks\\downloads\\addresses.csv')
df
# Out:
#     id  location_id                   address_1  address_2  \
# 0    1            1       2600 Middlefield Road        NaN
# 1    2            2            24 Second Avenue        NaN
# 2    3            3            24 Second Avenue        NaN
# 3    4            4            24 Second Avenue        NaN
# 4    5            5            24 Second Avenue        NaN
# 5    6            6           800 Middle Avenue        NaN
# 6    7            7              500 Arbor Road        NaN
# 7    8            8           800 Middle Avenue        NaN
# 8    9            9       2510 Middlefield Road        NaN
# 9   10           10       1044 Middlefield Road        NaN
# 10  11           11         2140 Euclid Avenue.        NaN
# 11  12           12       1044 Middlefield Road  2nd Floor
# 12  13           13         399 Marine Parkway.        NaN
# 13  14           14          660 Veterans Blvd.        NaN
# 14  15           15        1500 Valencia Street        NaN
# ...

# %%
pd.read_csv('C:\\Users\\viks\\downloads\\addresses.csv', header = None)
# bydefault pandas mai 1st row header hota hai agar wo nahi chaaiye toh header ka value none kardi ya kuch aur chaiye toh wo kard
# Out:
#      0            1                           2          3  \
# 0   id  location_id                   address_1  address_2
# 1    1            1       2600 Middlefield Road        NaN
# 2    2            2            24 Second Avenue        NaN
# 3    3            3            24 Second Avenue        NaN
# 4    4            4            24 Second Avenue        NaN
# 5    5            5            24 Second Avenue        NaN
# 6    6            6           800 Middle Avenue        NaN
# 7    7            7              500 Arbor Road        NaN
# 8    8            8           800 Middle Avenue        NaN
# 9    9            9       2510 Middlefield Road        NaN
# 10  10           10       1044 Middlefield Road        NaN
# 11  11           11         2140 Euclid Avenue.        NaN
# 12  12           12       1044 Middlefield Road  2nd Floor
# 13  13           13         399 Marine Parkway.        NaN
# 14  14           14          660 Veterans Blvd.        NaN
# ...

# %%
pd.read_csv('C:\\Users\\viks\\downloads\\addresses.csv', names = ["a", "b", "c", "d","e","f","g"])
# Out:
#               a                           b          c                    d  \
# id  location_id                   address_1  address_2                 city
# 1             1       2600 Middlefield Road        NaN         Redwood City
# 2             2            24 Second Avenue        NaN            San Mateo
# 3             3            24 Second Avenue        NaN            San Mateo
# 4             4            24 Second Avenue        NaN            San Mateo
# 5             5            24 Second Avenue        NaN            San Mateo
# 6             6           800 Middle Avenue        NaN           Menlo Park
# 7             7              500 Arbor Road        NaN           Menlo Park
# 8             8           800 Middle Avenue        NaN           Menlo Park
# 9             9       2510 Middlefield Road        NaN         Redwood City
# 10           10       1044 Middlefield Road        NaN         Redwood City
# ...

# %%
''' agar , ki jagah kuch aur value se seperated hau toh isme " sep" naam ka functiom usko change kardo 
for eg agar @ se seperated toh jaha header likha usi jagah pe sep = "@"
ye likhne wo phir @ pe seperate karega'''

# %%
df1 = pd.read_csv('C:\\Users\\viks\\downloads\\addresses.csv', skiprows = [1,3])

# %%
df1
# Out:
#     id  location_id                   address_1  address_2  \
# 0    2            2            24 Second Avenue        NaN
# 1    4            4            24 Second Avenue        NaN
# 2    5            5            24 Second Avenue        NaN
# 3    6            6           800 Middle Avenue        NaN
# 4    7            7              500 Arbor Road        NaN
# 5    8            8           800 Middle Avenue        NaN
# 6    9            9       2510 Middlefield Road        NaN
# 7   10           10       1044 Middlefield Road        NaN
# 8   11           11         2140 Euclid Avenue.        NaN
# 9   12           12       1044 Middlefield Road  2nd Floor
# 10  13           13         399 Marine Parkway.        NaN
# 11  14           14          660 Veterans Blvd.        NaN
# 12  15           15        1500 Valencia Street        NaN
# 13  16           16         1161 South Bernardo        NaN
# 14  17           17     409 South Spruce Avenue        NaN
# ...

# %%
df1.dtypes
# it shows the datatypes of each column
# Out:
# id                 int64
# location_id        int64
# address_1         object
# address_2         object
# city              object
# state_province    object
# postal_code       object
# country           object
# dtype: object

# %%
df1.head()
# shows 1st 5 columns agar koi aur caiye jese 2 ya 3 toh bracket mai (3) daala toh utne hi aayege
# Out:
#    id  location_id          address_1 address_2        city state_province  \
# 0   2            2   24 Second Avenue       NaN   San Mateo             CA
# 1   4            4   24 Second Avenue       NaN   San Mateo             CA
# 2   5            5   24 Second Avenue       NaN   San Mateo             CA
# 3   6            6  800 Middle Avenue       NaN  Menlo Park             CA
# 4   7            7     500 Arbor Road       NaN  Menlo Park             CA
#
#   postal_code country
# 0       94401      US
# 1       94401      US
# 2       94401      US
# 3  94025-9881      US
# 4       94025      US

# %%
df1.tail(2)
# Out:
#     id  location_id                   address_1  address_2           city  \
# 17  20           21          123 El Camino Real        NaN        Belmont
# 18  21           22  2013 Avenue of the fellows  Suite 100  San Francisco
#
#    state_province postal_code country
# 17             CA       94002      US
# 18             CA       94103      US

# %%
df.columns
# Out:
# Index(['id', 'location_id', 'address_1', 'address_2', 'city', 'state_province',
#        'postal_code', 'country'],
#       dtype='object')

# %%
a = df['city']
# iss method se ek time pe ek hi row ya column call kar sakte hai |

# %%
type(a)
# Out:
# pandas.core.series.Series

# %%
# series is equivalent to list

# %%
b = df[["city" , "country"]]

# %%
b
# Out:
#                    city country
# 0          Redwood City      US
# 1             San Mateo      US
# 2             San Mateo      US
# 3             San Mateo      US
# 4             San Mateo      US
# 5            Menlo Park      US
# 6            Menlo Park      US
# 7            Menlo Park      US
# 8          Redwood City      US
# 9          Redwood City      US
# 10         Redwood City      US
# 11         Redwood City      US
# 12         Redwood City      US
# 13         Redwood City      US
# 14        San Francisco      US
# 15            Sunnyvale      US
# 16  South San Francisco      US
# 17         Redwood City      US
# 18            San Mateo      US
# 19              Belmont      US
# 20        San Francisco      US

# %%
type(df[["city"]])
# double bracket means df and single bracket matlab list
# Out:
# pandas.core.frame.DataFrame

# %%
pd.read_csv("https://raw.githubusercontent.com/codeforamerica/ohana-api/master/data/sample-csv/phones.csv")
# Out:
#     id  contact_id  location_id  organization_id  service_id  country_prefix  \
# 0    1         NaN          1.0              NaN         NaN             NaN
# 1    2         NaN          1.0              NaN         NaN             NaN
# 2    3         NaN          2.0              NaN         NaN             NaN
# 3    4         NaN          2.0              NaN         NaN             NaN
# 4    5         NaN          3.0              NaN         NaN             NaN
# 5    6         NaN          3.0              NaN         NaN             NaN
# 6    7         NaN          4.0              NaN         NaN             NaN
# 7    8         NaN          4.0              NaN         NaN             NaN
# 8    9         NaN          5.0              NaN         NaN             NaN
# 9   10         NaN          5.0              NaN         NaN             NaN
# 10  11         NaN          6.0              NaN         NaN             NaN
# ...
