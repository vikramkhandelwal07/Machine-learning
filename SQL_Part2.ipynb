# %%
import mysql.connector as conn

# %%
mydb = conn.connect(host = "localhost" , user = "root" , passwd = "What the fuck.07")

# %%
cursor = mydb.cursor()

# %%
cursor.execute("show databases")

# %%
cursor.fetchall()
# Out:
# [('information_schema',),
#  ('mysql',),
#  ('performance_schema',),
#  ('sakila',),
#  ('sys',),
#  ('vikramsql',),
#  ('vikramsql2',),
#  ('world',)]

# %%
cursor.execute("select * from vikramsql.table2 ")

# %%
cursor.fetchall()
# Out:
# [(6, 4.0, 13.64, 4.49, 1.1, 71.78, 0.06, 8.75, 0.0, 0.0, 1),
#  (2, 1.51761, 13.89, 3.6, 1.36, 72.73, 0.48, 7.83, 0.0, 0.0, 1),
#  (3, 1.51618, 13.53, 3.55, 1.54, 72.99, 0.39, 7.78, 0.0, 0.0, 1),
#  (5, 1.51742, 13.27, 3.62, 1.24, 73.08, 0.55, 8.07, 0.0, 0.0, 1),
#  (6, 1.51596, 12.79, 3.61, 1.62, 72.97, 0.64, 8.07, 0.0, 0.26, 1),
#  (7, 1.51743, 13.3, 3.6, 1.14, 73.09, 0.58, 8.17, 0.0, 0.0, 1),
#  (8, 1.51756, 13.15, 3.61, 1.05, 73.24, 0.57, 8.24, 0.0, 0.0, 1),
#  (9, 1.51918, 14.04, 3.58, 1.37, 72.08, 0.56, 8.3, 0.0, 0.0, 1),
#  (10, 1.51755, 13.0, 3.6, 1.36, 72.99, 0.57, 8.4, 0.0, 0.11, 1),
#  (11, 1.51571, 12.72, 3.46, 1.56, 73.2, 0.67, 8.09, 0.0, 0.24, 1),
#  (12, 1.51763, 12.8, 3.66, 1.27, 73.01, 0.6, 8.56, 0.0, 0.0, 1),
#  (13, 1.51589, 12.88, 3.43, 1.4, 73.28, 0.69, 8.05, 0.0, 0.24, 1),
#  (14, 1.51748, 12.86, 3.56, 1.27, 73.21, 0.54, 8.38, 0.0, 0.17, 1),
#  (15, 1.51763, 12.61, 3.59, 1.31, 73.29, 0.58, 8.5, 0.0, 0.0, 1),
# ...

# %% [markdown]
# ## selecting some data on given conditions

# %%
cursor.execute("select col1, col5, col8 from vikramsql.table2")

# %%
cursor.fetchall()
# Out:
# [(6, 1.1, 8.75),
#  (2, 1.36, 7.83),
#  (3, 1.54, 7.78),
#  (5, 1.24, 8.07),
#  (6, 1.62, 8.07),
#  (7, 1.14, 8.17),
#  (8, 1.05, 8.24),
#  (9, 1.37, 8.3),
#  (10, 1.36, 8.4),
#  (11, 1.56, 8.09),
#  (12, 1.27, 8.56),
#  (13, 1.4, 8.05),
#  (14, 1.27, 8.38),
#  (15, 1.31, 8.5),
#  (16, 1.23, 8.39),
#  (17, 1.16, 8.7),
#  (18, 0.89, 9.15),
#  (19, 1.18, 8.89),
#  (20, 1.69, 8.44),
#  (21, 1.49, 8.52),
#  (22, 0.29, 9.0),
#  (23, 1.29, 8.7),
#  (24, 1.35, 8.59),
#  (25, 1.15, 8.43),
#  (26, 1.21, 8.53),
#  (27, 1.41, 8.43),
#  (28, 1.33, 8.43),
#  (29, 1.43, 8.54),
#  (30, 1.28, 8.49),
#  (31, 1.3, 8.69),
#  (32, 1.14, 8.55),
#  (33, 1.23, 8.56),
#  (34, 1.38, 8.55),
#  (35, 1.34, 8.75),
#  (36, 1.21, 8.57),
#  (37, 1.32, 8.78),
#  (38, 1.35, 8.68),
#  (39, 0.47, 9.57),
#  (40, 0.47, 9.57),
#  (41, 1.12, 8.77),
#  (42, 1.2, 8.64),
#  (43, 1.33, 8.59),
#  (44, 0.72, 9.74),
#  (45, 1.19, 8.76),
#  (46, 1.35, 9.0),
#  (47, 1.18, 8.83),
#  (48, 0.71, 9.82),
#  (49, 0.79, 10.02),
# ...

# %%
cursor.execute("select * from vikramsql.table2 WHERE col1 = 4")

# %%
cursor.fetchall()
# Out:
# []

# %% [markdown]
# ## Delete operation

# %%
cursor.execute("delete from vikramsql.table2 WHERE col1 = 4")

# %%
mydb.commit()

# %% [markdown]
# ## update operation

# %%
cursor.execute("UPDATE vikramsql.table2 SET col1 = 6 , col2 = 4 WHERE col1 = 4")

# %%
mydb.commit()

# %%
cursor.execute("select * from vikramsql.table2 WHERE col1 = 6")

# %%
cursor.fetchall()
# Out:
# [(6, 4.0, 13.64, 4.49, 1.1, 71.78, 0.06, 8.75, 0.0, 0.0, 1),
#  (6, 1.51596, 12.79, 3.61, 1.62, 72.97, 0.64, 8.07, 0.0, 0.26, 1),
#  (6, 4.0, 13.64, 4.49, 1.1, 71.78, 0.06, 8.75, 0.0, 0.0, 1),
#  (6, 1.51596, 12.79, 3.61, 1.62, 72.97, 0.64, 8.07, 0.0, 0.26, 1)]

# %% [markdown]
# ## group by

# %%
cursor.execute("select col1 , count(col1)  from vikramsql.table2 group by col1 order by col1")

# %%
cursor.fetchall()
# it will show that group mai ke element ka count kya hai for eg col1 mai 3 hai toh wo kitni bar hai isse pata chalega....
# jese isme 3--> 2 bar hua
# Out:
# [(2, 2),
#  (3, 2),
#  (5, 2),
#  (6, 4),
#  (7, 2),
#  (8, 2),
#  (9, 2),
#  (10, 2),
#  (11, 2),
#  (12, 2),
#  (13, 2),
#  (14, 2),
#  (15, 2),
#  (16, 2),
#  (17, 2),
#  (18, 2),
#  (19, 2),
#  (20, 2),
#  (21, 2),
#  (22, 2),
#  (23, 2),
#  (24, 2),
#  (25, 2),
#  (26, 2),
#  (27, 2),
#  (28, 2),
#  (29, 2),
#  (30, 2),
#  (31, 2),
#  (32, 2),
#  (33, 2),
#  (34, 2),
#  (35, 2),
#  (36, 2),
#  (37, 2),
#  (38, 2),
#  (39, 2),
#  (40, 2),
#  (41, 2),
#  (42, 2),
#  (43, 2),
#  (44, 2),
#  (45, 2),
#  (46, 2),
#  (47, 2),
#  (48, 2),
#  (49, 2),
#  (50, 2),
#  (51, 2),
#  (52, 2),
#  (53, 2),
#  (54, 2),
#  (55, 2),
#  (56, 2),
#  (57, 2),
#  (58, 2),
#  (59, 2),
#  (60, 2),
#  (61, 2),
#  (62, 2),
#  (63, 2),
#  (64, 2),
#  (65, 2),
#  (66, 2),
#  (67, 2),
#  (68, 2),
#  (69, 2),
#  (70, 2),
#  (71, 2),
#  (72, 2),
#  (73, 2),
#  (74, 2),
#  (75, 2),
#  (76, 2),
#  (77, 2),
#  (78, 2),
#  (79, 2),
#  (80, 2),
#  (81, 2),
#  (82, 2),
#  (83, 2),
#  (84, 2),
#  (85, 2),
# ...

# %% [markdown]
# ## to Delete a Table

# %%
cursor.execute("drop table vikramsql.table1")
mydb.commit()
# this will delete the table 1 from my database

# %%
cursor.execute("select * from vikramsql.table2")

# %%
cursor.fetchall()

# %%
cursor.execute("select * from vikramsql.table2 where col2 like '1.515%' ")

# %%
cursor.fetchall

# %%
cursor.execute("select * from(select * from vikramsql.table2 where col1 > 112) as a where col11 = 3")
# isme jo " as a likha hai wo alias hai waha a ki jagah vikram ya kuch bhi likhta toh bhi chalta "

# %%
cursor.fetchall()

# %%
cursor.execute("SELECT col1 FROM vikramsql.table2 GROUP BY col1 HAVING COUNT(col1) > 2 ")

# %%
cursor.fetchall()
# Out:
# [(6,)]
